# %% [markdown]
# <a href="https://colab.research.google.com/github/gravity0717/Capstone/blob/main/analysis_MUSINSA_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualize Data

# %%
import matplotlib.pyplot as plt
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_data=pd.read_csv('/content/drive/MyDrive/캡스톤/데이터만지기/refined_data')

# %%
plt.hist(df_data['clean_view'])
# Out:
# (array([1.5019e+04, 1.5370e+03, 2.0800e+02, 5.3000e+01, 1.8000e+01,
#         9.0000e+00, 2.0000e+00, 0.0000e+00, 3.0000e+00, 2.0000e+00]),
#  array([5.00000e+00, 3.06210e+03, 6.11920e+03, 9.17630e+03, 1.22334e+04,
#         1.52905e+04, 1.83476e+04, 2.14047e+04, 2.44618e+04, 2.75189e+04,
#         3.05760e+04]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # log 취하기

# %%
import math
_view=[]
log_view=[]
_view=df_data['clean_view']

for idx in _view:
  log_view.append(math.log(idx))

plt.hist(log_view)

df_data['log-view']=log_view

df_data.to_csv(('/content/drive/MyDrive/캡스톤/데이터만지기/refined_data'))

# %%
df2=pd.read_csv('/content/drive/MyDrive/캡스톤/데이터만지기/refined_data')
df2
# Out:
#        Unnamed: 0  Unnamed: 0.1  index         date  clean_view  log-view
# 0               0             0      1  2020.10.20         3426  8.139149
# 1               1             1      2  2020.10.20          302  5.710427
# 2               2             2      3  2020.10.20         1844  7.519692
# 3               3             3      4  2020.10.20          370  5.913503
# 4               4             4      5  2020.10.20          769  6.645091
# ...           ...           ...    ...          ...         ...       ...
# 16846       16846         16846  16880  2022.06.09          113  4.727388
# 16847       16847         16847  16881  2022.06.09          148  4.997212
# 16848       16848         16848  16882  2022.06.09          165  5.105945
# 16849       16849         16849  16883  2022.06.09          142  4.955827
# 16850       16850         16850  16884  2022.06.09          176  5.170484
#
# [16851 rows x 6 columns]

# %%
df3=pd.read_csv('/content/drive/MyDrive/캡스톤/데이터만지기/refined_data')

# %%
sub=pd.DataFrame()
sub['dif']=df_data2['clean_view'].sub(df_data['clean_view'])
sub['date']=df_data['date']
sub.dropna(inplace=True)
sub.head()
# Out:
#     dif         date
# 0  62.0  2020.10.20
# 1   0.0  2020.10.20
# 2  54.0  2020.10.20
# 3   7.0  2020.10.20
# 4   8.0  2020.10.20

# %%
sub=pd.DataFrame()
sub['dif']=df_data2['clean_view'].sub(df_data['clean_view'])
sub['date']=df_data['date']
sub.dropna(inplace=True)
sub.head()
# Out:
#     dif         date
# 0  62.0  2020.10.20
# 1   0.0  2020.10.20
# 2  54.0  2020.10.20
# 3   7.0  2020.10.20
# 4   8.0  2020.10.20

# %%
xs=sub['date'].to_list()			#dy_day(데이터 프레임)의 index(날짜, 시간)를 리스트로 저장 
ys=sub['dif'].to_list()		#dy_day(테이터 프레임)의 volume 필드를 리스트로 저장

plt.figure(figsize=(10, 6))			#그래프 크기 지정
plt.xlabel('date')				#그래프 x축 이름(label) 지정
plt.ylabel('difference')				#그래프 y축 이름(label) 지정

plt.bar(xs, ys, width=0.6, color='blue')	#리스트로 저장한 xs와 ys로 막대(bar) 그래프 플롯
# Out:
# <BarContainer object of 13696 artists>

# %%
str_expr="dif>2000"
df_q=sub.query(str_expr)
res=df_q.sort_values(by='date',ascending=True)
res
# Out:
#           dif         date
# 9887   2058.0  2021.12.08
# 9978   2413.0  2021.12.10
# 10001  2670.0  2021.12.10
# 10017  2709.0  2021.12.10
# 10033  2825.0  2021.12.13
# ...       ...          ...
# 13567  2299.0  2022.03.16
# 13590  2360.0  2022.03.16
# 13632  3840.0  2022.03.17
# 13624  2770.0  2022.03.17
# 13671  3673.0  2022.03.18
#
# [95 rows x 2 columns]
